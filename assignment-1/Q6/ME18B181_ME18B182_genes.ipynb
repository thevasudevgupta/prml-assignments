# %%
import pandas as pd

# %%
df = pd.read_csv("assignmentcounts.csv")
df
# Out:
#            Unnamed: 0  GTEX-1117F-0426-SM-5EGHI  GTEX-111CU-2026-SM-5GZZC  \
# 0     ENSG00000260534                         0                         0
# 1     ENSG00000227167                         0                         0
# 2     ENSG00000202382                        12                         3
# 3     ENSG00000179913                         0                         0
# 4     ENSG00000272247                         0                         0
# ...               ...                       ...                       ...
# 4439  ENSG00000269901                         2                         4
# 4440  ENSG00000231651                         0                         0
# 4441  ENSG00000275784                         0                         0
# 4442  ENSG00000207942                         0                         0
# 4443  ENSG00000212382                         0                         0
#
#       GTEX-111FC-0326-SM-5GZZ1  GTEX-111VG-2626-SM-5GZY2  \
# ...

# %%
import numpy as np
d = [np.unique(df[col]) for col in df.columns]
[d[i].shape for i in range(len(d))]
# Out:
# [(4444,),
#  (148,),
#  (135,),
#  (145,),
#  (148,),
#  (148,),
#  (139,),
#  (137,),
#  (149,),
#  (150,),
#  (149,),
#  (135,),
#  (142,),
#  (140,),
#  (144,),
#  (139,),
#  (136,),
#  (145,),
#  (141,),
#  (145,),
#  (146,),
#  (143,),
#  (134,),
#  (152,),
#  (137,),
#  (151,),
#  (148,),
#  (139,),
#  (139,),
#  (140,),
#  (147,),
#  (148,),
#  (142,),
#  (139,),
#  (154,),
#  (133,),
#  (132,),
#  (134,),
#  (136,),
#  (150,),
#  (158,),
#  (143,),
#  (160,),
#  (144,),
#  (156,),
#  (135,),
#  (145,),
#  (151,),
#  (135,),
#  (148,),
#  (132,),
#  (140,),
#  (142,),
#  (139,),
#  (134,),
#  (147,),
#  (138,),
#  (138,),
#  (140,),
#  (141,),
#  (140,),
#  (138,),
#  (143,),
#  (139,),
#  (143,),
#  (142,),
#  (155,),
#  (143,),
#  (145,),
#  (146,),
#  (141,),
#  (148,),
#  (142,),
#  (141,),
#  (150,),
#  (146,),
#  (140,),
#  (150,),
#  (147,),
#  (147,),
#  (142,),
#  (143,),
#  (134,),
#  (147,),
#  (145,),
#  (148,),
#  (142,),
#  (143,),
#  (144,),
#  (150,),
# ...

# %%
import matplotlib.pyplot as plt

for col in df.columns[1: 5]:
    data = df[col].value_counts()
    print(data)
    plt.hist(df[col])
    plt.show()
# Out:
# 0      3025
# 1       352
# 2       162
# 3       106
# 6        64
#        ...
# 44        1
# 78        1
# 304       1
# 71        1
# 226       1
# Name: GTEX-1117F-0426-SM-5EGHI, Length: 148, dtype: int64
# 0      3174
# 1       322
# 3       101
# 2       100
# 5        59
#        ...
# 81        1
# 52        1
# 78        1
# 174       1
# 650       1
# Name: GTEX-111CU-2026-SM-5GZZC, Length: 135, dtype: int64
# 0       3003
# 1        375
# 2        170
# 4         98
# 3         91
#         ...
# 265        1
# 5173       1
# 499        1
# 142        1
# 1977       1
# Name: GTEX-111FC-0326-SM-5GZZ1, Length: 145, dtype: int64
# 0      3083
# 1       334
# 2       160
# 4        84
# 3        81
#        ...
# 815       1
# 348       1
# 76        1
# 284       1
# 518       1
# Name: GTEX-111VG-2626-SM-5GZY2, Length: 148, dtype: int64
